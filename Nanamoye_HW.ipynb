# %%
# !pip install ase
# !pip install nglview
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.1 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 5.9 MB/s eta 0:00:0000:0100:01m
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for nglview: filename=nglview-3.0.8-py3-none-any.whl size=10216160 sha256=d777a5cc33282ae471a316ed0c7ce18a655ef88641b6b65d028393f3ab958dcf
#   Stored in directory: /home/jovyan/.cache/pip/wheels/44/4d/79/91ae837c351b9bc95392237aa0bb564ff0a570572502877188
# Successfully built nglview
# ...
